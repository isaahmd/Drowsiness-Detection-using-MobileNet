# %%
import os
import shutil
import glob
from tqdm import tqdm

# %%
raw_dir= r'E:/Kuliah/Sem 5/Proglan/Projek/mrlEyes_2018_01'
for dirpath, dirmane, filenames in os.walk(raw_dir):
    for i in tqdm ([f for f in filenames if f.endswith('.png')]):
        if i.split('_')[4]=='1':
            shutil.copy(src=dirpath + '/'+i, dst=r"data/buka")
        elif i.split('_')[4]=='0':
            shutil.copy(src=dirpath + '/'+i, dst=r"data/tutup")
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|██████████| 10257/10257 [01:28<00:00, 115.39it/s]
